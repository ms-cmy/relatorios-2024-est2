# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy

# %%
valoes = np.random.randint(0, 100, size=(100000, 10))

# %%
sns.histplot(np.sum(valoes, axis=1), )
# Out:
# <Axes: ylabel='Count'>

# %%
scipy.stats.norm.fit(np.sum(valoes, axis=1))
# Out:
# (np.float64(494.80065), np.float64(91.13945616239708))

# %%
valores_from = scipy.stats.norm.rvs(4500, 91, size= 10_000)

# %%
sns.histplot(valores_from)
# Out:
# <Axes: ylabel='Count'>
